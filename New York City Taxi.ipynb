# %%
#This project involves analyzing 2017 yellow taxi trip data to extract insights about passenger behavior, trip patterns, and fare structures. 
#By examining various variables such as pickup/dropoff times, distances, and fares, 
#the analysis aims to enhance understanding of urban transportation trends 
#and inform strategies for optimizing taxi services.

# %%
import pandas as pd
import numpy as np

# RUN THIS CELL TO IMPORT YOUR DATA.
df = pd.read_csv('2017_Yellow_Taxi_Trip_Data.csv')
print("done")
# Out:
# done

# %%
df.head(10)
# Out:
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0    24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1    35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2   106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3    38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4    30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
# 5    23345809         2   03/25/2017 8:34:11 PM   03/25/2017 8:42:11 PM
# 6    37660487         2   05/03/2017 7:04:09 PM   05/03/2017 8:03:47 PM
# 7    69059411         2   08/15/2017 5:41:06 PM   08/15/2017 6:03:05 PM
# 8     8433159         2   02/04/2017 4:17:07 PM   02/04/2017 4:29:14 PM
# 9    95294817         1   11/10/2017 3:20:29 PM   11/10/2017 3:40:55 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# ...

# %%
####Question 1: When reviewing the df.info() output, what do you notice about the different variables? Are there any null values? Are all of the variables numeric? Does anything else stand out?
#Question 2: When reviewing the df.describe() output, what do you notice about the distributions of each variable? Are there any questionable values?

#==> Question 1: The DataFrame contains a variety of data types: float64, int64, and object.
#The DataFrame has a RangeIndex starting from 0 and going up to 22,698.
#Each column in the DataFrame is labeled with a unique name.
#The columns represent different aspects of taxi trip data, such as pickup and dropoff times, passenger count, trip distance, payment information, fare amounts, and more.
#The "Non-Null Count" for each column indicates that there are no missing values in any of the columns since the count matches the total number of entries (22,699) for all columns.
#The "memory usage" of the DataFrame is approximately 3.1+ MB, which gives an idea of the memory required to store the DataFrame in memory.

#Question 2: When reviewing the df.describe() output, Regarding trip distance, most rides are between 1-3 miles, but the maximum is over 33 miles. Regarding fare amount, the distribution is worth considering. The maximum fare amount is a much larger value ($1000) than the 25-75 percent range of values. Also, it's questionable how there are negative values for fare amount.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0      VendorID  passenger_count  trip_distance  \
# count  2.269900e+04  22699.000000     22699.000000   22699.000000
# mean   5.675849e+07      1.556236         1.642319       2.913313
# std    3.274493e+07      0.496838         1.285231       3.653171
# min    1.212700e+04      1.000000         0.000000       0.000000
# 25%    2.852056e+07      1.000000         1.000000       0.990000
# 50%    5.673150e+07      2.000000         1.000000       1.610000
# 75%    8.537452e+07      2.000000         2.000000       3.060000
# max    1.134863e+08      2.000000         6.000000      33.960000
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean       1.043394    162.412353    161.527997      1.336887     13.026629
# std        0.708391     66.633373     70.139691      0.496211     13.243791
# ...

# %%
df_sort = df.sort_values(by=["tip_amount"],ascending=False)["tip_amount"]
df_sort.head(18)



# Sort the data by tip amount from max to min value
# Out:
# 8476     200.00
# 6064      55.50
# 13861     51.64
# 12511     46.69
# 984       42.29
# 14825     28.00
# 9714      25.20
# 6708      25.20
# 17934     25.00
# 5210      22.22
# 5536      21.30
# 7281      20.16
# 11542     20.00
# 11902     20.00
# 1252      20.00
# 11269     20.00
# 15109     20.00
# 18130     19.85
# Name: tip_amount, dtype: float64

# %%
#Question 1: Sort your first variable (trip_distance) from maximum to minimum value, do the values seem normal?

df_sort = df.sort_values(by=['trip_distance'],ascending=False)
df_sort.head(10)

# Sort the data by trip distance from maximum to minimum value
# Out:
#        Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 9280     51810714         2  06/18/2017 11:33:25 PM  06/19/2017 12:12:38 AM
# 13861    40523668         2   05/19/2017 8:20:21 AM   05/19/2017 9:20:30 AM
# 6064     49894023         2  06/13/2017 12:30:22 PM   06/13/2017 1:37:51 PM
# 10291    76319330         2  09/11/2017 11:41:04 AM  09/11/2017 12:18:58 PM
# 29       94052446         2   11/06/2017 8:30:50 PM  11/07/2017 12:00:00 AM
# 18130    90375786         1   10/26/2017 2:45:01 PM   10/26/2017 4:12:49 PM
# 5792     68023798         2   08/11/2017 2:14:01 PM   08/11/2017 3:17:31 PM
# 15350    77309977         2   09/14/2017 1:44:44 PM   09/14/2017 2:34:29 PM
# 10302    43431843         1   05/15/2017 8:11:34 AM   05/15/2017 9:03:16 AM
# 2592     51094874         2   06/16/2017 6:51:20 PM   06/16/2017 7:41:42 PM
#
#        passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# ...

# %%
# Sort the data by total amount and print the top 20 values

df_sort = df.sort_values(by=["total_amount"],ascending=False)

df_sort.head(20)
# Out:
#        Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 8476     11157412         1   02/06/2017 5:50:10 AM   02/06/2017 5:51:08 AM
# 20312   107558404         2   12/19/2017 9:40:46 AM   12/19/2017 9:40:55 AM
# 13861    40523668         2   05/19/2017 8:20:21 AM   05/19/2017 9:20:30 AM
# 12511   107108848         2   12/17/2017 6:24:24 PM   12/17/2017 6:24:42 PM
# 15474    55538852         2   06/06/2017 8:55:01 PM   06/06/2017 8:55:06 PM
# 6064     49894023         2  06/13/2017 12:30:22 PM   06/13/2017 1:37:51 PM
# 16379   101198443         2  11/30/2017 10:41:11 AM  11/30/2017 11:31:45 AM
# 3582    111653084         1  01/01/2017 11:53:01 PM  01/01/2017 11:53:42 PM
# 11269    51920669         1  06/19/2017 12:51:17 AM  06/19/2017 12:52:12 AM
# 9280     51810714         2  06/18/2017 11:33:25 PM  06/19/2017 12:12:38 AM
# 1928     51087145         1   06/16/2017 6:30:08 PM   06/16/2017 7:18:50 PM
# ...

# %%
# Sort the data by total amount and print ONLY the top 20 values without showing the other data in tables


df_sort = df.sort_values(by=
    ['total_amount'], ascending=False)['total_amount']
df_sort.head(20)
# Out:
# 8476     1200.29
# 20312     450.30
# 13861     258.21
# 12511     233.74
# 15474     211.80
# 6064      179.06
# 16379     157.06
# 3582      152.30
# 11269     151.82
# 9280      150.30
# 1928      137.80
# 10291     131.80
# 6708      126.00
# 11608     123.30
# 908       121.56
# 7281      120.96
# 18130     119.31
# 13621     115.94
# 13359     111.95
# 29        111.38
# Name: total_amount, dtype: float64

# %%
df_sort = df.sort_values(by=
    ['total_amount'], ascending=False)['total_amount']
df_sort.tail(20)
# Out:
# 14283      0.31
# 19067      0.30
# 10506      0.00
# 5722       0.00
# 4402       0.00
# 22566      0.00
# 1646      -3.30
# 18565     -3.80
# 314       -3.80
# 5758      -3.80
# 5448      -4.30
# 4423      -4.30
# 10281     -4.30
# 8204      -4.80
# 20317     -4.80
# 11204     -5.30
# 14714     -5.30
# 17602     -5.80
# 20698     -5.80
# 12944   -120.30
# Name: total_amount, dtype: float64

# %%
# How many of each payment type are represented in the data?

payment_type=df['payment_type'].value_counts()
payment_type
# Out:
# 1    15265
# 2     7267
# 3      121
# 4       46
# Name: payment_type, dtype: int64
